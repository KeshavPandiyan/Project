# %% [markdown]
# ### Import Libraries

# %%
import os

# %%
import warnings

# %%
warnings.simplefilter('ignore')

# %% [markdown]
# ### Import DataHandling Libraries

# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# ### Import DataVisualization Library

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Import required components from image processing library
# scikit-image
#     . imread
#     . imshow
#     . resize
#     . rgb2gray

# %%
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %% [markdown]
# ### Working Directory

# %%
Tony = os.listdir("C:/Users/Keshav/Documents/College/Prag Classes/Phase 2/Face Recognition/Tony")

# %%
Tyler = os.listdir("C:/Users/Keshav/Documents/College/Prag Classes/Phase 2/Face Recognition/Tyler")

# %%
Saul = os.listdir("C:/Users/Keshav/Documents/College/Prag Classes/Phase 2/Face Recognition/Saul")

# %% [markdown]
# ### Reading Image as a matrix of numbers

# %%
limit = 10
tony_images = [None]*limit
j = 0
for i in Tony:
    if(j<limit):
        tony_images[j] = imread("C:/Users/Keshav/Documents/College/Prag Classes/Phase 2/Face Recognition/Tony/"+i)
        j+=1
    else:
        break

# %%
limit = 10
tyler_images = [None]*limit
j = 0
for i in Tyler:
    if(j<limit):
        tyler_images[j] = imread("C:/Users/Keshav/Documents/College/Prag Classes/Phase 2/Face Recognition/Tyler/"+i)
        j+=1
    else:
        break

# %%
limit = 10
saul_images = [None]*limit
j = 0
for i in Saul:
    if(j<limit):
        saul_images[j] = imread("C:/Users/Keshav/Documents/College/Prag Classes/Phase 2/Face Recognition/Saul/"+i)
        j+=1
    else:
        break

# %% [markdown]
# ### Image Show

# %%
imshow(tony_images[1])

# %%
imshow(tyler_images[1])

# %%
imshow(saul_images[1])

# %% [markdown]
# ### Greyscale

# %%
tony_images[1].shape
# Out:
# (612, 463, 3)

# %% [markdown]
# ### rgb2gray

# %%
tyler_gray = [None]*limit
j = 0
for i in Tyler:
    if(j<limit):
        tyler_gray[j] = rgb2gray(tyler_images[j])
        j+=1
    else:
        break

# %%
tony_gray = [None]*limit
j = 0
for i in Tony:
    if(j<limit):
        tony_gray[j] = rgb2gray(tony_images[j])
        j+=1
    else:
        break

# %%
saul_gray = [None]*limit
j = 0
for i in Saul:
    if(j<limit):
        saul_gray[j] = rgb2gray(saul_images[j])
        j+=1
    else:
        break

# %% [markdown]
# ### Matrix Resizing

# %%
for j in range (10):
    tny = tony_gray[j]
    tony_gray[j]=resize(tny,(512,512))

# %%
for j in range (10):
    ty = tyler_gray[j]
    tyler_gray[j]=resize(ty,(512,512))

# %%
for j in range (10):
    sl = saul_gray[j]
    saul_gray[j]=resize(sl,(512,512))

# %%
imshow(tyler_gray[8])

# %% [markdown]
# ### Convert image from Matrix form to Vector form

# %%
len_of_images_tyler = len(tyler_gray)

# %%
len_of_images_tyler
# Out:
# 10

# %%
image_size_tyler = tyler_gray[1].shape

# %%
image_size_tyler
# Out:
# (512, 512)

# %%
flatten_size_tyler = image_size_tyler[0]*image_size_tyler[1]

# %%
flatten_size_tyler
# Out:
# 262144

# %%
for i in range(len_of_images_tyler):
    tyler_gray[i] = np.ndarray.flatten(tyler_gray[i]).reshape(flatten_size_tyler,1)

# %%
tyler_gray[1].shape
# Out:
# (262144, 1)

# %%
tyler_gray = np.dstack(tyler_gray)

# %%
tyler_gray.shape
# Out:
# (262144, 1, 10)

# %%
tyler_gray= np.rollaxis(tyler_gray, axis = 2, start = 0)

# %%
tyler_gray.shape
# Out:
# (10, 262144, 1)

# %%
tyler_gray = tyler_gray.reshape(len_of_images_tyler, flatten_size_tyler)

# %%
tyler_gray.shape
# Out:
# (10, 262144)

# %%
tyler_data = pd.DataFrame(tyler_gray)

# %%
tyler_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.054322  0.054322  0.054322  0.054322  0.054322  0.054440  0.054463
# 1  0.269758  0.257572  0.241776  0.233995  0.228169  0.213886  0.194019
# 2  0.813268  0.788885  0.774280  0.763596  0.738739  0.712805  0.691956
# 3  0.547339  0.547339  0.547250  0.546822  0.546684  0.546684  0.546684
# 4  0.657226  0.656788  0.654567  0.654160  0.651794  0.650944  0.651645
# 5  0.220958  0.228247  0.231352  0.230849  0.234827  0.236301  0.233258
# 6  0.543289  0.539662  0.531721  0.524481  0.519001  0.514972  0.515991
# 7  0.196259  0.196499  0.186371  0.176645  0.167382  0.158154  0.148972
# 8  0.068314  0.068962  0.069619  0.069642  0.069017  0.067923  0.067230
# 9  0.232289  0.229281  0.228369  0.231470  0.235366  0.229000  0.228845
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.054463  0.057195  0.058101  ...  0.085694  0.085694  0.086127  0.087666
# ...

# %%
len_of_images_tony = len(tony_gray)
image_size_tony = tony_gray[1].shape
flatten_size_tony = image_size_tony[0]*image_size_tony[1]
for i in range(len_of_images_tony):
    tony_gray[i] = np.ndarray.flatten(tony_gray[i]).reshape(flatten_size_tony,1)
tony_gray = np.dstack(tony_gray)
tony_gray= np.rollaxis(tony_gray, axis = 2, start = 0)
tony_gray = tony_gray.reshape(len_of_images_tony, flatten_size_tony)

# %%
tony_gray.shape
# Out:
# (10, 262144)

# %%
tony_data = pd.DataFrame(tony_gray)

# %%
tony_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.092231  0.092231  0.092231  0.092231  0.092231  0.092355  0.092658
# 1  0.156322  0.129183  0.137113  0.316185  0.579197  0.737135  0.733531
# 2  0.637224  0.637224  0.637494  0.639927  0.641146  0.641146  0.640860
# 3  0.023529  0.023529  0.023529  0.023529  0.023529  0.023529  0.023529
# 4  0.615626  0.615626  0.615626  0.615626  0.615626  0.615626  0.615626
# 5  0.157917  0.157917  0.157917  0.156633  0.154979  0.154914  0.154914
# 6  0.150694  0.150694  0.150694  0.150694  0.150694  0.150694  0.150694
# 7  0.988250  0.988250  0.988250  0.988250  0.988250  0.988250  0.988250
# 8  0.477155  0.476006  0.472589  0.465147  0.459205  0.454339  0.451641
# 9  0.004123  0.004092  0.000565  0.000565  0.000575  0.001056  0.004851
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.092671  0.092671  0.092671  ...  0.074327  0.074341  0.075538  0.077836
# ...

# %%
len_of_images_saul = len(saul_gray)
image_size_saul = saul_gray[1].shape
flatten_size_saul = image_size_saul[0]*image_size_saul[1]
for i in range(len_of_images_saul):
    saul_gray[i] = np.ndarray.flatten(saul_gray[i]).reshape(flatten_size_saul,1)
saul_gray = np.dstack(saul_gray)
saul_gray= np.rollaxis(saul_gray, axis = 2, start = 0)
saul_gray = saul_gray.reshape(len_of_images_saul, flatten_size_saul)

# %%
saul_gray.shape
# Out:
# (10, 262144)

# %%
saul_data = pd.DataFrame(saul_gray)

# %%
saul_data
# Out:
#      0         1         2         3         4         5         6       \
# 0
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.988250  0.988250  0.988250  0.988250  0.988250  0.988250  0.988250
# 1   0.657226  0.656788  0.654567  0.654160  0.651794  0.650944  0.651645
# 2   0.114180  0.114180  0.114180  0.114180  0.114180  0.114180  0.114180
# 3   0.704700  0.695374  0.673462  0.644278  0.614468  0.584621  0.556948
# 4   0.746974  0.734836  0.698304  0.658772  0.634350  0.640531  0.663569
# 5   0.637224  0.637224  0.637494  0.639927  0.641146  0.641146  0.640860
# 6   0.130929  0.130951  0.132552  0.135539  0.138526  0.143252  0.147023
# 7   0.156322  0.129183  0.137113  0.316185  0.579197  0.737135  0.733531
# 8   0.023529  0.023529  0.023529  0.023529  0.023529  0.023529  0.023529
# 9   0.852549  0.852549  0.852549  0.852549  0.852549  0.852549  0.852549
# 10  0.150694  0.150694  0.150694  0.150694  0.150694  0.150694  0.150694
# 11  0.220958  0.228247  0.231352  0.230849  0.234827  0.236301  0.233258
# ...

# %% [markdown]
# ### Export the Dataset

# %%
Actors.to_csv("C:/Users/Keshav/Documents/College/Prag Classes/csv/Image_Recognition_Actors.csv")

# %% [markdown]
# ### D1 Assigning Dependent and Independent Variables

# %%
x = Actors.values[:,:-1]

# %%
y = Actors.values[:,-1]

# %%
x
# Out:
# array([[0.9882501960784315, 0.9882501960784315, 0.9882501960784313, ...,
#         0.13914800967347388, 0.1354074297317804, 0.13509921715231502],
#        [0.6572258823529413, 0.6567880039350543, 0.6545665452190148, ...,
#         0.11084730392161224, 0.12008303007280693, 0.1257952624760936],
#        [0.11417999999999999, 0.11418, 0.11418, ..., 0.01853322504492367,
#         0.019718185508578435, 0.02346517999387255],
#        ...,
#        [0.06831395421928724, 0.06896209389551529, 0.06961934396879876,
#         ..., 0.2904441056603682, 0.3026384588110644, 0.31156341469274057],
#        [0.15791691176470593, 0.15791691176470593, 0.1579169117647059,
#         ..., 0.1342744170843386, 0.14999188983393652,
#         0.15289014722038716],
#        [0.5212158767281327, 0.5263645511881511, 0.5318760557167204, ...,
#         0.017122745098039214, 0.01712274509803921, 0.017122745098039214]],
#       dtype=object)

# %%
y
# Out:
# array(['Tony', 'Tyler', 'Saul', 'Saul', 'Saul', 'Tony', 'Saul', 'Tony',
#        'Tony', 'Saul', 'Tony', 'Tyler', 'Tyler', 'Saul', 'Tony', 'Tyler',
#        'Tyler', 'Tyler', 'Saul', 'Tyler', 'Saul', 'Tyler', 'Tony', 'Saul',
#        'Tony', 'Tyler', 'Tony', 'Tyler', 'Tony', 'Saul'], dtype=object)

# %% [markdown]
# ### D2 Assigning and Training Dataset

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)

# %% [markdown]
# ### E1 Support Vector Machines Algorithm

# %%
from sklearn import svm

# %% [markdown]
# ### E2 Support Vector Machine Implementation
# SVC - support Vector Classification

# %%
clf = svm.SVC()
clf.fit(x_train, y_train)
# Out:
# SVC()

# %% [markdown]
# ### F1 Image Prediction

# %%
y_pred = clf.predict(x_test)

# %%
y_pred
# Out:
# array(['Tony', 'Tony', 'Tony', 'Tyler', 'Saul', 'Saul'], dtype=object)

# %% [markdown]
# ### F2 Prediction Visualisation

# %%
for i in range(6):
    predicted_images = (np.reshape(x_test[i],(512,512)).astype(np.float64))
    plt.title('predicted label: {0}'.format(y_pred[i]))
    plt.imshow(predicted_images, interpolation='nearest', cmap = 'gray')
    plt.show()

# %%
from sklearn import metrics

# %%
accuracy = metrics.accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.16666666666666666

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[0, 2, 0],
#        [2, 1, 1],
#        [0, 0, 0]], dtype=int64)
